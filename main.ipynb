# %%
# %load_ext autoreload
# %autoreload 2

from load_data.load_data import MPKGraphLoader, TramGraphLoader, BusGraphLoader
from map_utils import get_map, get_hex_area, TransferConfig, get_izochrone_map
import warnings
warnings.filterwarnings('ignore')

# %%
loader_2023 = MPKGraphLoader.from_pickle('./data/mpk_graph_loader_2023.pkl')
loader_2024 = MPKGraphLoader.from_pickle('./data/mpk_graph_loader_2024.pkl')

tram_loader_2023 = TramGraphLoader.from_pickle('./data/tram_graph_loader_2023.pkl')
tram_loader_2024 = TramGraphLoader.from_pickle('./data/tram_graph_loader_2024.pkl')

bus_loader_2023 = BusGraphLoader.from_pickle('./data/bus_graph_loader_2023.pkl')
bus_loader_2024 = BusGraphLoader.from_pickle('./data/bus_graph_loader_2024.pkl')

# %%
get_izochrone_map(8, loader_2024, TransferConfig('dworzec główny', 5, 5), [5, 15, 30, 45, 60, 75])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82004d9e4c3fbd015b4f51bb672a4b0b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82004d9e4c3fbd015b4f51bb672a4b0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82004d9e4c3fbd015b4f51bb672a4b0b = L.map(
#                 &quot;map_82004d9e4c3fbd015b4f51bb672a4b0b&quot;,
#                 {
#                     center: [51.09873535235658, 17.03477641658594],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_82004d9e4c3fbd015b4f51bb672a4b0b);
#
#
#
#
#
#             var tile_layer_6f74dd92b875ca510cd4886369509d6d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6f74dd92b875ca510cd4886369509d6d.addTo(map_82004d9e4c3fbd015b4f51bb672a4b0b);
#
#
#             map_82004d9e4c3fbd015b4f51bb672a4b0b.fitBounds(
#                 [[51.08695860574811, 17.00972101818567], [51.110512098965046, 17.059831814986218]],
#                 {}
#             );
#
#
#         function geo_json_46684d3d43bbdad8c005c36fdbfa5a9f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#7ddf64&quot;, &quot;fillColor&quot;: &quot;#7ddf64&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.05, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_46684d3d43bbdad8c005c36fdbfa5a9f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_46684d3d43bbdad8c005c36fdbfa5a9f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_46684d3d43bbdad8c005c36fdbfa5a9f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_46684d3d43bbdad8c005c36fdbfa5a9f = L.geoJson(null, {
#                 onEachFeature: geo_json_46684d3d43bbdad8c005c36fdbfa5a9f_onEachFeature,
#
#                 style: geo_json_46684d3d43bbdad8c005c36fdbfa5a9f_styler,
#                 pointToLayer: geo_json_46684d3d43bbdad8c005c36fdbfa5a9f_pointToLayer,
#         });
#
#         function geo_json_46684d3d43bbdad8c005c36fdbfa5a9f_add (data) {
#             geo_json_46684d3d43bbdad8c005c36fdbfa5a9f
#                 .addData(data);
#         }
#             geo_json_46684d3d43bbdad8c005c36fdbfa5a9f_add({&quot;bbox&quot;: [17.00972101818567, 51.08695860574811, 17.059831814986218, 51.110512098965046], &quot;features&quot;: [{&quot;bbox&quot;: [17.04482238665984, 51.0998001297942, 17.059831814986218, 51.108359666184434], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[17.04724110619108, 51.10729627662969], [17.04482238665984, 51.10301647284564], [17.04990797851247, 51.0998001297942], [17.05741233279161, 51.100863407059016], [17.059831814986218, 51.10514313964616], [17.05474618032268, 51.108359666184434], [17.04724110619108, 51.10729627662969]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;881e20409dfffff&quot;, &quot;properties&quot;: {&quot;__folium_color&quot;: &quot;#7ddf64&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [17.034900325300914, 51.094455977496146, 17.04990797851247, 51.10301647284564], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[17.03731820023325, 51.101952420298026], [17.034900325300914, 51.09767213709569], [17.039985873975102, 51.094455977496146], [17.04748934084431, 51.095519917666095], [17.04990797851247, 51.0998001297942], [17.04482238665984, 51.10301647284564], [17.03731820023325, 51.101952420298026]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;881e204083fffff&quot;, &quot;properties&quot;: {&quot;__folium_color&quot;: &quot;#7ddf64&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [17.012391487339656, 51.09126128146769, 17.027397026

# %%
get_map(8, loader_2023)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e84d0d4c12e12facca4d08ec1595b0b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e84d0d4c12e12facca4d08ec1595b0b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e84d0d4c12e12facca4d08ec1595b0b7 = L.map(
#                 &quot;map_e84d0d4c12e12facca4d08ec1595b0b7&quot;,
#                 {
#                     center: [51.12064250164131, 16.99925667725629],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e84d0d4c12e12facca4d08ec1595b0b7);
#
#
#
#
#
#             var tile_layer_aa546e56928b07914d4b30764f7df60e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aa546e56928b07914d4b30764f7df60e.addTo(map_e84d0d4c12e12facca4d08ec1595b0b7);
#
#
#             map_e84d0d4c12e12facca4d08ec1595b0b7.fitBounds(
#                 [[51.04195487488349, 16.828038415973655], [51.19933012839915, 17.17047493853893]],
#                 {}
#             );
#
#
#         function geo_json_df35a14917b82a4aa90af0f182141590_styler(feature) {
#             switch(feature.id) {
#                 case &quot;881e204049fffff&quot;: case &quot;881e204705fffff&quot;: case &quot;881e204743fffff&quot;: case &quot;881e20475dfffff&quot;: case &quot;881e204005fffff&quot;: case &quot;881e204235fffff&quot;: case &quot;881e20431bfffff&quot;: case &quot;881e204213fffff&quot;: case &quot;881e2042a5fffff&quot;: case &quot;881e20451bfffff&quot;: case &quot;881e204033fffff&quot;: case &quot;881e204521fffff&quot;: case &quot;881e204097fffff&quot;: case &quot;881e20420dfffff&quot;: case &quot;881e20415bfffff&quot;: case &quot;881e204001fffff&quot;: case &quot;881e20406bfffff&quot;: case &quot;881e204769fffff&quot;: case &quot;881e20451dfffff&quot;: case &quot;881e20428dfffff&quot;: case &quot;881e204731fffff&quot;: case &quot;881e204307fffff&quot;: case &quot;881e204055fffff&quot;: case &quot;881e2041d7fffff&quot;: case &quot;881e2051b7fffff&quot;: case &quot;881e204509fffff&quot;: case &quot;881e20442dfffff&quot;: case &quot;881e204197fffff&quot;: case &quot;881e20435bfffff&quot;: case &quot;881e204e13fffff&quot;: case &quot;881e204723fffff&quot;: case &quot;881e204233fffff&quot;: case &quot;881e204315fffff&quot;: case &quot;881e20462dfffff&quot;: case &quot;881e204e59fffff&quot;: case &quot;881e204729fffff&quot;: case &quot;881e204247fffff&quot;: case &quot;881e20452bfffff&quot;: case &quot;881e204555fffff&quot;: case &quot;881e20474dfffff&quot;: case &quot;881e2041cbfffff&quot;: case &quot;881e204767fffff&quot;: case &quot;881e204303fffff&quot;: case &quot;881e204063fffff&quot;: case &quot;881e204553fffff&quot;: case &quot;881e204569fffff&quot;: case &quot;881e205187fffff&quot;: case &quot;881e204529fffff&quot;: case &quot;881e20456bfffff&quot;: case &quot;881e204e0bfffff&quot;: case &quot;881e2042b5fffff&quot;: case &quot;881e204229fffff&quot;: case &quot;881e204297fffff&quot;: case &quot;881e204359fffff&quot;: case &quot;881e204341fffff&quot;: case &quot;881e2040cbfffff&quot;: case &quot;881e204e4dfffff&quot;: case &quot;881e204549fffff&quot;: case &quot;881e204e0dfffff&quot;: case &quot;881e204547fffff&quot;: case &quot;881e204357fffff&quot;: case &quot;881e20422bfffff&quot;: case &quot;881e2042ddfffff&quot;: case &quot;881e2042c7fffff&quot;: case &quot;881e204313fffff&quot;: case &quot;881e2051bdfffff&quot;: case &quot;881e205537fffff&quot;:
#                     return {&quot;color&quot;: &quot;#a50026&quot;, &quot;fillColor&quot;: &quot;#a50026&quot;, &quot;fillOpacity&quot;: 0.5, &quot;opacity&quot;: 0.05, &quot;weight&quot;: 2};
#                 case &quot;881e2041ddfffff&quot;: case &quot;881e204019fffff&quot;: case &quot;881e2040c7fffff&quot;: case &quot;881e2042b1fffff&quot;: case &quot;881e204265fffff&quot;: case &quot;881e2055b3fffff&quot;: case &quot;881e204239fffff&quot;: case &quot;881e204317fffff&quot;: case &quot;881e2042a1fffff&quot;: case &quot;881e204763fffff&quot;: case &quot;881e204e6dfffff&quot;: case &quot;881e204e51fffff&quot;: case &quot;881e2042b3fffff&quot;: case &quot;881e2040ddfffff&quot;: case &quot;881e204227fffff&quot;: case &quot;881e20470bfffff&quot;: case &quot;881e204283fffff&quot;: case &quot;8

# %%
transfer_cfg = TransferConfig('wrocławski park przemysłowy', 15, 5)

# %%
m1 = get_map(8, loader_2023, transfer_cfg)
m1.save("maps/map_2023.html")

m2 = get_map(8, loader_2024, transfer_cfg)
m2.save("maps/map_2024.html")

m1 = get_map(8, tram_loader_2023, transfer_cfg)
m1.save("maps/tram_map_2023.html")

m2 = get_map(8, tram_loader_2024, transfer_cfg)
m2.save("maps/tram_map_2024.html")

m1 = get_map(8, bus_loader_2023, transfer_cfg)
m1.save("maps/bus_map_2023.html")

m2 = get_map(8, bus_loader_2024, transfer_cfg)
m2.save("maps/bus_map_2024.html")

# %%
get_hex_area(8, loader_2023, transfer_cfg)
# Out:
# 119.01666666666668
